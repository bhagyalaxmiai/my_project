# %%
import pandas as pd
import pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from pymongo.mongo_client import MongoClient

# mongodb_url_key = "mongodb+srv://clarityai:N0lTZ4zedDxGbn9N@cluster0.qketnjc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0&tlsCAFile=isrgrootx1.pem"
              



import certifi
ca = certifi.where()

# pip install certifi
# Create a new client and connect to the server
# client = MongoClient(uri, server_api=ServerApi('1'))
client = MongoClient("mongodb+srv://veenagabnave:aa5xcuda8yrgb6Zd@cluster0.otxvmcd.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=ca)
# client = MongoClient("mongodb+srv://bhagyalaxmi:VSPt0ujgqu2sUKv0@cluster0.qketnjc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0",tlsCAFile=ca)
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
print (client)
# Out:
# MongoClient(host=['ac-c8q3fc3-shard-00-02.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-01.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-00.qketnjc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', tlscafile='isrgrootx1.pem', authsource='admin', replicaset='atlas-bcz8by-shard-0', tls=True)

# %%
database = client['db-customer-churn']
collection = database['predict-telco-customer-churn']
data = pd.read_csv("E:\\clarity.ai\\telco-customer-churn\\predict_data.csv")
collection.insert_many(data.to_dict(orient='records'))
# Out:
# InsertManyResult(['6590cd223999e61fced5e816', '6590cd223999e61fced5e817', '6590cd223999e61fced5e818', '6590cd223999e61fced5e819', '6590cd223999e61fced5e81a', '6590cd223999e61fced5e81b', '6590cd223999e61fced5e81c', '6590cd223999e61fced5e81d', '6590cd223999e61fced5e81e', '6590cd223999e61fced5e81f', '6590cd223999e61fced5e820', '6590cd223999e61fced5e821', '6590cd223999e61fced5e822', '6590cd223999e61fced5e823', '6590cd223999e61fced5e824', '6590cd223999e61fced5e825', '6590cd223999e61fced5e826', '6590cd223999e61fced5e827', '6590cd223999e61fced5e828', '6590cd223999e61fced5e829', '6590cd223999e61fced5e82a', '6590cd223999e61fced5e82b', '6590cd223999e61fced5e82c', '6590cd223999e61fced5e82d', '6590cd223999e61fced5e82e', '6590cd223999e61fced5e82f', '6590cd223999e61fced5e830', '6590cd223999e61fced5e831', '6590cd223999e61fced5e832', '6590cd223999e61fced5e833', '6590cd223999e61fced5e834', '6590cd223999e61fced5e835', '6590cd223999e61fced5e836', '6590cd223999e61fced5e837', '6590cd223999e61fced5e838', '6590cd223999e61fced5e839', '6590cd223999e61fced5e83a', '6590cd223999e61fced5e83b', '6590cd223999e61fced5e83c', '6590cd223999e61fced5e83d', '6590cd223999e61fced5e83e', '6590cd223999e61fced5e83f', '6590cd223999e61fced5e840', '6590cd223999e61fced5e841', '6590cd223999e61fced5e842', '6590cd223999e61fced5e843', '6590cd223999e61fced5e844', '6590cd223999e61fced5e845', '6590cd223999e61fced5e846', '6590cd223999e61fced5e847', '6590cd223999e61fced5e848', '6590cd223999e61fced5e849', '6590cd223999e61fced5e84a', '6590cd223999e61fced5e84b', '6590cd223999e61fced5e84c', '6590cd223999e61fced5e84d', '6590cd223999e61fced5e84e', '6590cd223999e61fced5e84f', '6590cd223999e61fced5e850', '6590cd223999e61fced5e851', '6590cd223999e61fced5e852', '6590cd223999e61fced5e853', '6590cd223999e61fced5e854', '6590cd223999e61fced5e855', '6590cd223999e61fced5e856', '6590cd223999e61fced5e857', '6590cd223999e61fced5e858', '6590cd223999e61fced5e859', '6590cd223999e61fced5e85a', '6590cd223999e61fced5e85b', '6590cd223999e61fced5e85c', '6590cd223999e61fced5e85d', '6590cd223999e61fced5e85e', '6590cd223999e61fced5e85f', '6590cd223999e61fced5e860', '6590cd223999e61fced5e861', '6590cd223999e61fced5e862', '6590cd223999e61fced5e863', '6590cd223999e61fced5e864', '6590cd223999e61fced5e865', '6590cd223999e61fced5e866', '6590cd223999e61fced5e867', '6590cd223999e61fced5e868', '6590cd223999e61fced5e869', '6590cd223999e61fced5e86a', '6590cd223999e61fced5e86b', '6590cd223999e61fced5e86c', '6590cd223999e61fced5e86d', '6590cd223999e61fced5e86e', '6590cd223999e61fced5e86f', '6590cd223999e61fced5e870', '6590cd223999e61fced5e871', '6590cd223999e61fced5e872', '6590cd223999e61fced5e873', '6590cd223999e61fced5e874', '6590cd223999e61fced5e875', '6590cd223999e61fced5e876', '6590cd223999e61fced5e877', '6590cd223999e61fced5e878', '6590cd223999e61fced5e879', '6590cd223999e61fced5e87a', '6590cd223999e61fced5e87b', '6590cd223999e61fced5e87c', '6590cd223999e61fced5e87d', '6590cd223999e61fced5e87e', '6590cd223999e61fced5e87f', '6590cd223999e61fced5e880', '6590cd223999e61fced5e881', '6590cd223999e61fced5e882', '6590cd223999e61fced5e883', '6590cd223999e61fced5e884', '6590cd223999e61fced5e885', '6590cd223999e61fced5e886', '6590cd223999e61fced5e887', '6590cd223999e61fced5e888', '6590cd223999e61fced5e889', '6590cd223999e61fced5e88a', '6590cd223999e61fced5e88b', '6590cd223999e61fced5e88c', '6590cd223999e61fced5e88d', '6590cd223999e61fced5e88e', '6590cd223999e61fced5e88f', '6590cd223999e61fced5e890', '6590cd223999e61fced5e891', '6590cd223999e61fced5e892', '6590cd223999e61fced5e893', '6590cd223999e61fced5e894', '6590cd223999e61fced5e895', '6590cd223999e61fced5e896', '6590cd223999e61fced5e897', '6590cd223999e61fced5e898', '6590cd223999e61fced5e899', '6590cd223999e61fced5e89a', '6590cd223999e61fced5e89b', '6590cd223999e61fced5e89c', '6590cd223999e61fced5e89d', '6590cd223999e61fced5e89e', '6590cd223999e61fced5e89f', '6590cd223999e61fced5e8a0', '6590cd223999e61fced5e8a1', '6590cd223999e61fced5e8a2', '6590cd223999e61fced5e8a3', '6590c ...

# %%
# collection = database['telco-customer-churn']

# %%
# collection
# Out:
# Collection(Database(MongoClient(host=['ac-c8q3fc3-shard-00-02.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-01.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-00.qketnjc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', tlscafile='isrgrootx1.pem', authsource='admin', replicaset='atlas-bcz8by-shard-0', tls=True), 'db-customer-churn'), 'telco-customer-churn')

# %% [markdown]
# ### Delete all documents from collection

# %%
# collection.delete_many({})

# %%
# collection
