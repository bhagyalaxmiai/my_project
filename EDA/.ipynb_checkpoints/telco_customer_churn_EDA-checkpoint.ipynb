# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('bmh')
pd.set_option('display.max_columns', None)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('training_data.csv')

# %% [markdown]
# ### walkthrough the dataset before analysis

# %%
data.head()
# Out:
#                         _id  customerID  gender  SeniorCitizen Partner  \
# 0  65ebff6becc39074aab45f70  7590-VHVEG  Female              0     Yes
# 1  65ebff6becc39074aab45f71  5575-GNVDE    Male              0      No
# 2  65ebff6becc39074aab45f72  3668-QPYBK    Male              0      No
# 3  65ebff6becc39074aab45f73  7795-CFOCW    Male              0      No
# 4  65ebff6becc39074aab45f74  9237-HQITU  Female              0      No
#
#   Dependents  tenure PhoneService     MultipleLines InternetService  \
# 0         No       1           No  No phone service             DSL
# 1         No      34          Yes                No             DSL
# 2         No       2          Yes                No             DSL
# 3         No      45           No  No phone service             DSL
# 4         No       2          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges TotalCharges Churn
# 0           29.85        29.85    No
# 1           56.95       1889.5    No
# 2           53.85       108.15   Yes
# 3           42.30      1840.75    No
# 4           70.70       151.65   Yes

# %%
data.tail()
# Out:
#                            _id  customerID  gender  SeniorCitizen Partner  \
# 7038  65ebff6becc39074aab47aee  6840-RESVB    Male              0     Yes
# 7039  65ebff6becc39074aab47aef  2234-XADUH  Female              0     Yes
# 7040  65ebff6becc39074aab47af0  4801-JZAZL  Female              0     Yes
# 7041  65ebff6becc39074aab47af1  8361-LTMKD    Male              1     Yes
# 7042  65ebff6becc39074aab47af2  3186-AJIEK    Male              0      No
#
#      Dependents  tenure PhoneService     MultipleLines InternetService  \
# 7038        Yes      24          Yes               Yes             DSL
# 7039        Yes      72          Yes               Yes     Fiber optic
# 7040        Yes      11           No  No phone service             DSL
# 7041         No       4          Yes               Yes     Fiber optic
# 7042         No      66          Yes                No     Fiber optic
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 7038            Yes           No              Yes         Yes         Yes
# 7039             No          Yes              Yes          No         Yes
# 7040            Yes           No               No          No          No
# 7041             No           No               No          No          No
# 7042            Yes           No              Yes         Yes         Yes
#
#      StreamingMovies        Contract PaperlessBilling  \
# 7038             Yes        One year              Yes
# 7039             Yes        One year              Yes
# 7040              No  Month-to-month              Yes
# 7041              No  Month-to-month              Yes
# 7042             Yes        Two year              Yes
#
#                   PaymentMethod  MonthlyCharges TotalCharges Churn
# 7038               Mailed check           84.80       1990.5    No
# 7039    Credit card (automatic)          103.20       7362.9    No
# 7040           Electronic check           29.60       346.45    No
# 7041               Mailed check           74.40        306.6   Yes
# 7042  Bank transfer (automatic)          105.65       6844.5    No

# %%
print(f"Total records : {data.shape[0]}")
# Out:
# Total records : 7043

# %%
print(f"Total features : {data.shape[1]}")
# Out:
# Total features : 22

# %%
data.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               7043 non-null   object
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   int64
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7043 non-null   object
#  21  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(19)
# memory usage: 1.2+ MB

# %%
data['SeniorCitizen'] = data['SeniorCitizen'].astype('O')
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               7043 non-null   object
#  1   customerID        7043 non-null   object
#  2   gender            7043 non-null   object
#  3   SeniorCitizen     7043 non-null   object
#  4   Partner           7043 non-null   object
#  5   Dependents        7043 non-null   object
#  6   tenure            7043 non-null   int64
#  7   PhoneService      7043 non-null   object
#  8   MultipleLines     7043 non-null   object
#  9   InternetService   7043 non-null   object
#  10  OnlineSecurity    7043 non-null   object
#  11  OnlineBackup      7043 non-null   object
#  12  DeviceProtection  7043 non-null   object
#  13  TechSupport       7043 non-null   object
#  14  StreamingTV       7043 non-null   object
#  15  StreamingMovies   7043 non-null   object
#  16  Contract          7043 non-null   object
#  17  PaperlessBilling  7043 non-null   object
#  18  PaymentMethod     7043 non-null   object
#  19  MonthlyCharges    7043 non-null   float64
#  20  TotalCharges      7032 non-null   float64
#  21  Churn             7043 non-null   object
# dtypes: float64(2), int64(1), object(19)
# memory usage: 1.2+ MB

# %%
numerical_columns = data.select_dtypes(include=['int64','float64']).columns.tolist()
print(f"Numerical columns : {numerical_columns}")
print(f"Numerical columns : {len(numerical_columns)}")
# Out:
# Numerical columns : ['tenure', 'MonthlyCharges', 'TotalCharges']
# Numerical columns : 3

# %%
categorical_columns = data.select_dtypes(include=['object']).columns.tolist()
print(f"categorical columns : {categorical_columns}")
print(f"categorical columns : {len(categorical_columns)}")
# Out:
# categorical columns : ['_id', 'customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn']
# categorical columns : 19

# %% [markdown]
# ### Target Feature

# %%
print(f"target feature is : 'Churn'")
# Out:
# target feature is : 'Churn'

# %%
print(f"Unique values in target feature{data['Churn'].unique()}")
# Out:
# Unique values in target feature['No' 'Yes']

# %%
print(f"Unique values in target feature : {len(data['Churn'].unique())}")
# Out:
# Unique values in target feature : 2

# %% [markdown]
# ### Observation :
#     1. Binary classification problem
#     2. Its in categorical form, need to transform

# %% [markdown]
# # Step 1 : Summary statistics

# %%
summary_stats = data[numerical_columns].describe()
summary_stats
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
data[data['tenure'] == 0]
# Out:
#                            _id  customerID  gender SeniorCitizen Partner  \
# 488   65ebff6becc39074aab46158  4472-LVYGI  Female             0     Yes
# 753   65ebff6becc39074aab46261  3115-CZMZD    Male             0      No
# 936   65ebff6becc39074aab46318  5709-LVOEQ  Female             0     Yes
# 1082  65ebff6becc39074aab463aa  4367-NUYAO    Male             0     Yes
# 1340  65ebff6becc39074aab464ac  1371-DWPAZ  Female             0     Yes
# 3331  65ebff6becc39074aab46c73  7644-OMVMY    Male             0     Yes
# 3826  65ebff6becc39074aab46e62  3213-VVOLG    Male             0     Yes
# 4380  65ebff6becc39074aab4708c  2520-SGTTA  Female             0     Yes
# 5218  65ebff6becc39074aab473d2  2923-ARZLG    Male             0     Yes
# 6670  65ebff6becc39074aab4797e  4075-WKNIU  Female             0     Yes
# 6754  65ebff6becc39074aab479d2  2775-SEFEE    Male             0      No
#
#      Dependents  tenure PhoneService     MultipleLines InternetService  \
# 488         Yes       0           No  No phone service             DSL
# 753         Yes       0          Yes                No              No
# 936         Yes       0          Yes                No             DSL
# 1082        Yes       0          Yes               Yes              No
# 1340        Yes       0           No  No phone service             DSL
# 3331        Yes       0          Yes                No              No
# 3826        Yes       0          Yes               Yes              No
# 4380        Yes       0          Yes                No              No
# 5218        Yes       0          Yes                No              No
# 6670        Yes       0          Yes               Yes             DSL
# 6754        Yes       0          Yes               Yes             DSL
#
#            OnlineSecurity         OnlineBackup     DeviceProtection  \
# 488                   Yes                   No                  Yes
# 753   No internet service  No internet service  No internet service
# 936                   Yes                  Yes                  Yes
# 1082  No internet service  No internet service  No internet service
# 1340                  Yes                  Yes                  Yes
# 3331  No internet service  No internet service  No internet service
# 3826  No internet service  No internet service  No internet service
# 4380  No internet service  No internet service  No internet service
# 5218  No internet service  No internet service  No internet service
# 6670                   No                  Yes                  Yes
# 6754                  Yes                  Yes                   No
#
#               TechSupport          StreamingTV      StreamingMovies  Contract  \
# 488                   Yes                  Yes                   No  Two year
# 753   No internet service  No internet service  No internet service  Two year
# 936                    No                  Yes                  Yes  Two year
# 1082  No internet service  No internet service  No internet service  Two year
# 1340                  Yes                  Yes                   No  Two year
# 3331  No internet service  No internet service  No internet service  Two year
# 3826  No internet service  No internet service  No internet service  Two year
# 4380  No internet service  No internet service  No internet service  Two year
# 5218  No internet service  No internet service  No internet service  One year
# 6670                  Yes                  Yes                   No  Two year
# 6754                  Yes                   No                   No  Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 488               Yes  Bank transfer (automatic)           52.55
# 753                No               Mailed check           20.25
# 936                No               Mailed check           80.85
# 1082               No               Mailed check           25.75
# 1340               No    Credit card (automatic)           56.05
# 3331               No               Mailed check           19.85
# 3826               No               Mailed check           25.35
# 4380               No               Mailed check           20.00
# 5218              Yes               Mailed check           19.70
# 6670               No               Mailed check           73.35
# 6754              Yes  Bank transfer (automatic)           61.90
#
#       TotalCharges Churn
# 488            NaN    No
# 753            NaN    No
# 936            NaN    No
# 1082           NaN    No
# 1340           NaN    No
# 3331           NaN    No
# 3826           NaN    No
# 4380           NaN    No
# 5218           NaN    No
# 6670           NaN    No
# 6754           NaN    No

# %%
len(data[data['tenure'] == 0])
# Out:
# 11

# %% [markdown]
# ### Step 2 : Data Visualization

# %%
sns.set(style='whitegrid')

fig, axes = plt.subplots(nrows= len(numerical_columns), ncols =2, figsize=(8,3*len(numerical_columns)))

for i, col in enumerate(numerical_columns):
    sns.histplot(data[col], kde=True, ax=axes[i,0], bins=30)
    axes[i,0].set_title(f"{col} Distribution ") 
    
    sns.boxplot(x=col, data=data, ax=axes[i,1])
    axes[i,1].set_title(f"{col} Box Plot")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 3 : Corelation Analysis

# %% [markdown]
# ### find the interrelation between numeric feature interrelation

# %%
correlation_matrix = data[numerical_columns].corr()
plt.figure(figsize =(5,4))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidth=0.5)

plt.title('Correlation Heatmap')

plt.show()

# %%
correlation_matrix
# Out:
#                  tenure  MonthlyCharges  TotalCharges
# tenure          1.00000        0.247900      0.825880
# MonthlyCharges  0.24790        1.000000      0.651065
# TotalCharges    0.82588        0.651065      1.000000

# %% [markdown]
# ###
#
# strong positive correlation
#
# moderate positive correlation
#
# weak positive correlation
#
# negative correlation
