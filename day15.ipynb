# %%
import pandas as pd
from pprint import pprint
from pymongo.mongo_client import MongoClient

mongodb_url_key = "mongodb+srv://clarityai:N0lTZ4zedDxGbn9N@cluster0.qketnjc.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0&tlsCAFile=isrgrootx1.pem"
              

# Create a new client and connect to the server
client = MongoClient(mongodb_url_key)

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
print (client)
# Out:
# MongoClient(host=['ac-c8q3fc3-shard-00-00.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-01.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-02.qketnjc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', tlscafile='isrgrootx1.pem', authsource='admin', replicaset='atlas-bcz8by-shard-0', tls=True)

# %%
database = client['db-customer-churn']
collection = database['telco-customer-churn']
data = pd.read_csv("E:\\clarity.ai\\telco-customer-churn\\Telco-customer-churn.csv")
collection.insert_many(data.to_dict(orient='records'))
# Out:
# InsertManyResult([ObjectId('65ebff6becc39074aab45f70'), ObjectId('65ebff6becc39074aab45f71'), ObjectId('65ebff6becc39074aab45f72'), ObjectId('65ebff6becc39074aab45f73'), ObjectId('65ebff6becc39074aab45f74'), ObjectId('65ebff6becc39074aab45f75'), ObjectId('65ebff6becc39074aab45f76'), ObjectId('65ebff6becc39074aab45f77'), ObjectId('65ebff6becc39074aab45f78'), ObjectId('65ebff6becc39074aab45f79'), ObjectId('65ebff6becc39074aab45f7a'), ObjectId('65ebff6becc39074aab45f7b'), ObjectId('65ebff6becc39074aab45f7c'), ObjectId('65ebff6becc39074aab45f7d'), ObjectId('65ebff6becc39074aab45f7e'), ObjectId('65ebff6becc39074aab45f7f'), ObjectId('65ebff6becc39074aab45f80'), ObjectId('65ebff6becc39074aab45f81'), ObjectId('65ebff6becc39074aab45f82'), ObjectId('65ebff6becc39074aab45f83'), ObjectId('65ebff6becc39074aab45f84'), ObjectId('65ebff6becc39074aab45f85'), ObjectId('65ebff6becc39074aab45f86'), ObjectId('65ebff6becc39074aab45f87'), ObjectId('65ebff6becc39074aab45f88'), ObjectId('65ebff6becc39074aab45f89'), ObjectId('65ebff6becc39074aab45f8a'), ObjectId('65ebff6becc39074aab45f8b'), ObjectId('65ebff6becc39074aab45f8c'), ObjectId('65ebff6becc39074aab45f8d'), ObjectId('65ebff6becc39074aab45f8e'), ObjectId('65ebff6becc39074aab45f8f'), ObjectId('65ebff6becc39074aab45f90'), ObjectId('65ebff6becc39074aab45f91'), ObjectId('65ebff6becc39074aab45f92'), ObjectId('65ebff6becc39074aab45f93'), ObjectId('65ebff6becc39074aab45f94'), ObjectId('65ebff6becc39074aab45f95'), ObjectId('65ebff6becc39074aab45f96'), ObjectId('65ebff6becc39074aab45f97'), ObjectId('65ebff6becc39074aab45f98'), ObjectId('65ebff6becc39074aab45f99'), ObjectId('65ebff6becc39074aab45f9a'), ObjectId('65ebff6becc39074aab45f9b'), ObjectId('65ebff6becc39074aab45f9c'), ObjectId('65ebff6becc39074aab45f9d'), ObjectId('65ebff6becc39074aab45f9e'), ObjectId('65ebff6becc39074aab45f9f'), ObjectId('65ebff6becc39074aab45fa0'), ObjectId('65ebff6becc39074aab45fa1'), ObjectId('65ebff6becc39074aab45fa2'), ObjectId('65ebff6becc39074aab45fa3'), ObjectId('65ebff6becc39074aab45fa4'), ObjectId('65ebff6becc39074aab45fa5'), ObjectId('65ebff6becc39074aab45fa6'), ObjectId('65ebff6becc39074aab45fa7'), ObjectId('65ebff6becc39074aab45fa8'), ObjectId('65ebff6becc39074aab45fa9'), ObjectId('65ebff6becc39074aab45faa'), ObjectId('65ebff6becc39074aab45fab'), ObjectId('65ebff6becc39074aab45fac'), ObjectId('65ebff6becc39074aab45fad'), ObjectId('65ebff6becc39074aab45fae'), ObjectId('65ebff6becc39074aab45faf'), ObjectId('65ebff6becc39074aab45fb0'), ObjectId('65ebff6becc39074aab45fb1'), ObjectId('65ebff6becc39074aab45fb2'), ObjectId('65ebff6becc39074aab45fb3'), ObjectId('65ebff6becc39074aab45fb4'), ObjectId('65ebff6becc39074aab45fb5'), ObjectId('65ebff6becc39074aab45fb6'), ObjectId('65ebff6becc39074aab45fb7'), ObjectId('65ebff6becc39074aab45fb8'), ObjectId('65ebff6becc39074aab45fb9'), ObjectId('65ebff6becc39074aab45fba'), ObjectId('65ebff6becc39074aab45fbb'), ObjectId('65ebff6becc39074aab45fbc'), ObjectId('65ebff6becc39074aab45fbd'), ObjectId('65ebff6becc39074aab45fbe'), ObjectId('65ebff6becc39074aab45fbf'), ObjectId('65ebff6becc39074aab45fc0'), ObjectId('65ebff6becc39074aab45fc1'), ObjectId('65ebff6becc39074aab45fc2'), ObjectId('65ebff6becc39074aab45fc3'), ObjectId('65ebff6becc39074aab45fc4'), ObjectId('65ebff6becc39074aab45fc5'), ObjectId('65ebff6becc39074aab45fc6'), ObjectId('65ebff6becc39074aab45fc7'), ObjectId('65ebff6becc39074aab45fc8'), ObjectId('65ebff6becc39074aab45fc9'), ObjectId('65ebff6becc39074aab45fca'), ObjectId('65ebff6becc39074aab45fcb'), ObjectId('65ebff6becc39074aab45fcc'), ObjectId('65ebff6becc39074aab45fcd'), ObjectId('65ebff6becc39074aab45fce'), ObjectId('65ebff6becc39074aab45fcf'), ObjectId('65ebff6becc39074aab45fd0'), ObjectId('65ebff6becc39074aab45fd1'), ObjectId('65ebff6becc39074aab45fd2'), ObjectId('65ebff6becc39074aab45fd3'), ObjectId('65ebff6becc39074aab45fd4'), ObjectId('65ebff6becc39074aab45fd5'), ObjectId('65ebff6becc39074aab45fd6'), ObjectId('65ebff6becc39074aab45fd7'), ObjectId('65ebff6becc39074aab4 ...

# %%
collection = database['telco-customer-churn']

# %%
collection
# Out:
# Collection(Database(MongoClient(host=['ac-c8q3fc3-shard-00-00.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-01.qketnjc.mongodb.net:27017', 'ac-c8q3fc3-shard-00-02.qketnjc.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', tlscafile='isrgrootx1.pem', authsource='admin', replicaset='atlas-bcz8by-shard-0', tls=True), 'db-customer-churn'), 'telco-customer-churn')
